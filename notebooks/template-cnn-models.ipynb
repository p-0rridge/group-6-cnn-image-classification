# %% [markdown]
# ## 1. Import libraries

# %% [markdown]
# ## 2. Load split data

# %% [markdown]
# ## 3. Create TensorFlow datasets

# %% [markdown]
# ## 4. Define model

# %% [markdown]
# ## 5. Compile model

# %% [markdown]
# ## 6. Train model

# %% [markdown]
# ## 7. Evaluate on test dataset

# %% [markdown]
# ## 8. Plot accuracy/loss curves

# %% [markdown]
# ## 9. Save model and results

# %% [markdown]
# ## 10. Write short conclusion
